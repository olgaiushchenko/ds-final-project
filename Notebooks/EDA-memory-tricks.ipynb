# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 999)

# %%
df = pd.read_csv('Fire_Department_Calls_for_Service.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (19,20,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (4715699, 34)

# %%
#memory usage: 1.2+ GB
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4715699 entries, 0 to 4715698
# Data columns (total 34 columns):
# Call Number                             int64
# Unit ID                                 object
# Incident Number                         int64
# Call Type                               object
# Call Date                               object
# Watch Date                              object
# Received DtTm                           object
# Entry DtTm                              object
# Dispatch DtTm                           object
# Response DtTm                           object
# On Scene DtTm                           object
# Transport DtTm                          object
# Hospital DtTm                           object
# Call Final Disposition                  object
# Available DtTm                          object
# Address                                 object
# City                                    object
# Zipcode of Incident                     float64
# Battalion                               object
# Station Area                            object
# Box                                     object
# Original Priority                       object
# Priority                                object
# Final Priority                          int64
# ALS Unit                                bool
# Call Type Group                         object
# Number of Alarms                        int64
# Unit Type                               object
# Unit sequence in call dispatch          float64
# Fire Prevention District                object
# Supervisor District                     object
# Neighborhooods - Analysis Boundaries    object
# Location                                object
# RowID                                   object
# dtypes: bool(1), float64(2), int64(4), object(27)
# memory usage: 1.2+ GB

# %%
#makes memory usage: 7.9 GB due to more detailed numbers to get an accurate number.
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4715699 entries, 0 to 4715698
# Data columns (total 34 columns):
# Call Number                             int64
# Unit ID                                 object
# Incident Number                         int64
# Call Type                               object
# Call Date                               object
# Watch Date                              object
# Received DtTm                           object
# Entry DtTm                              object
# Dispatch DtTm                           object
# Response DtTm                           object
# On Scene DtTm                           object
# Transport DtTm                          object
# Hospital DtTm                           object
# Call Final Disposition                  object
# Available DtTm                          object
# Address                                 object
# City                                    object
# Zipcode of Incident                     float64
# Battalion                               object
# Station Area                            object
# Box                                     object
# Original Priority                       object
# Priority                                object
# Final Priority                          int64
# ALS Unit                                bool
# Call Type Group                         object
# Number of Alarms                        int64
# Unit Type                               object
# Unit sequence in call dispatch          float64
# Fire Prevention District                object
# Supervisor District                     object
# Neighborhooods - Analysis Boundaries    object
# Location                                object
# RowID                                   object
# dtypes: bool(1), float64(2), int64(4), object(27)
# memory usage: 7.9 GB

# %%
for dtype in ['float','int','object','bool']:
    selected_dtype = df.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for float columns: 23.99 MB
# Average memory usage for int columns: 28.78 MB
# Average memory usage for object columns: 282.68 MB
# Average memory usage for bool columns: 2.25 MB

# %% [markdown]
# We can use the function pd.to_numeric() to downcast our numeric types. We'll use DataFrame.select_dtypes to select only the integer columns, then we'll optimize the types and compare the memory usage.

# %%
def mem_usage(pandas_obj):
    if isinstance(pandas_obj,pd.DataFrame):
        usage_b = pandas_obj.memory_usage(deep=True).sum()
    else: # we assume if not a df it's a series
        usage_b = pandas_obj.memory_usage(deep=True)
    usage_mb = usage_b / 1024 ** 2 # convert bytes to megabytes
    return "{:03.2f} MB".format(usage_mb)

df_int = df.select_dtypes(include=['int'])
converted_int = df_int.apply(pd.to_numeric,downcast='unsigned')

print(mem_usage(df_int))
print(mem_usage(converted_int))

compare_ints = pd.concat([df_int.dtypes,converted_int.dtypes],axis=1)
compare_ints.columns = ['before','after']
compare_ints.apply(pd.Series.value_counts)
# Out:
# 143.91 MB
# 44.97 MB
#         before  after
# uint8      NaN    2.0
# uint32     NaN    2.0
# int64      4.0    NaN

# %% [markdown]
# Lets do the same thing with our float columns.

# %%
df_float = df.select_dtypes(include=['float'])
converted_float = df_float.apply(pd.to_numeric,downcast='float')

print(mem_usage(df_float))
print(mem_usage(converted_float))

compare_floats = pd.concat([df_float.dtypes,converted_float.dtypes],axis=1)
compare_floats.columns = ['before','after']
compare_floats.apply(pd.Series.value_counts)
# Out:
# 71.96 MB
# 35.98 MB
#          before  after
# float32     NaN    2.0
# float64     2.0    NaN

# %%
optimized_df = df.copy()

optimized_df[converted_int.columns] = converted_int
optimized_df[converted_float.columns] = converted_float

print(mem_usage(df))
print(mem_usage(optimized_df))
# Out:
# 1191.77 MB
# 1056.85 MB

# %% [markdown]
# write a loop to iterate over each object column, check if the number of unique values is less than 50%, and if so, convert it to the category type.

# %%
converted_obj = pd.DataFrame()
df_obj = df.select_dtypes(include=['object']).copy()

for col in df_obj.columns:
    num_unique_values = len(df_obj[col].unique())
    num_total_values = len(df_obj[col])
    if num_unique_values / num_total_values < 0.5:
        converted_obj.loc[:,col] = df_obj[col].astype('category')
    else:
        converted_obj.loc[:,col] = df_obj[col]

# %%
print(mem_usage(df_obj))
print(mem_usage(converted_obj))

compare_obj = pd.concat([df_obj.dtypes,converted_obj.dtypes],axis=1)
compare_obj.columns = ['before','after']
compare_obj.apply(pd.Series.value_counts)
# Out:
# 971.40 MB
# 743.80 MB
#           before  after
# object      27.0      4
# category     NaN      2
# category     NaN      2
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1
# category     NaN      1

# %%
optimized_df.head()
# Out:
#                                                                           0  \
# Call Number                                                         1030101
# Unit ID                                                                 E18
# Incident Number                                                      306091
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:00:29 PM
# Entry DtTm                                           04/12/2000 09:01:40 PM
# Dispatch DtTm                                        04/12/2000 09:02:00 PM
# Response DtTm                                                           NaN
# On Scene DtTm                                                           NaN
# Transport DtTm                                                          NaN
# Hospital DtTm                                                           NaN
# Call Final Disposition                                                Other
# Available DtTm                                                          NaN
# Address                                              2000 Block of 37TH AVE
# City                                                                     SF
# Zipcode of Incident                                                   94116
# Battalion                                                               B08
# Station Area                                                             18
# Box                                                                     757
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                            ENGINE
# Unit sequence in call dispatch                                            1
# Fire Prevention District                                                  8
# Supervisor District                                                       4
# Neighborhooods - Analysis Boundaries                        Sunset/Parkside
# Location                              (37.7487247711275, -122.495504020186)
# RowID                                                         001030101-E18
#
#                                                                           1  \
# Call Number                                                         1030104
# Unit ID                                                                 M14
# Incident Number                                                       30612
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:09:02 PM
# Entry DtTm                                           04/12/2000 09:10:17 PM
# Dispatch DtTm                                        04/12/2000 09:10:29 PM
# Response DtTm                                        04/12/2000 09:12:11 PM
# On Scene DtTm                                        04/12/2000 09:19:36 PM
# Transport DtTm                                       04/12/2000 09:43:57 PM
# Hospital DtTm                                        04/12/2000 10:03:33 PM
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 10:23:57 PM
# Address                                              1700 Block of 43RD AVE
# City                                                                     SF
# Zipcode of Incident                                                   94122
# Battalion                                                               B08
# Station Area                                                             23
# Box                                                                    7651
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                               True
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                             MEDIC
# Unit sequence in call dispatch                                            2
# Fire Prevention District                                                  8
# Supervisor District                                                       4
# Neighborhooods - Analysis Boundaries                        Sunset/Parkside
# Location                              (37.7540326780595, -122.502185504543)
# RowID                                                         001030104-M14
#
#                                                                           2  \
# Call Number                                                         1030106
# Unit ID                                                                 M36
# Incident Number                                                       30614
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:09:44 PM
# Entry DtTm                                           04/12/2000 09:10:56 PM
# Dispatch DtTm                                        04/12/2000 09:11:47 PM
# Response DtTm                                                           NaN
# On Scene DtTm                                        04/12/2000 09:14:11 PM
# Transport DtTm                                       04/12/2000 09:59:31 PM
# Hospital DtTm                                        04/12/2000 10:10:06 PM
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 10:43:40 PM
# Address                                                  0 Block of FELL ST
# City                                                                     SF
# Zipcode of Incident                                                   94102
# Battalion                                                               B02
# Station Area                                                             36
# Box                                                                    3111
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                             MEDIC
# Unit sequence in call dispatch                                            1
# Fire Prevention District                                                  2
# Supervisor District                                                       6
# Neighborhooods - Analysis Boundaries                             Tenderloin
# Location                              (37.7764405100838, -122.418481123408)
# RowID                                                         001030106-M36
#
#                                                                           3  \
# Call Number                                                         1030107
# Unit ID                                                                 E01
# Incident Number                                                       30615
# Call Type                                                            Alarms
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:13:47 PM
# Entry DtTm                                           04/12/2000 09:13:51 PM
# Dispatch DtTm                                        04/12/2000 09:14:13 PM
# Response DtTm                                        04/12/2000 09:15:58 PM
# On Scene DtTm                                        04/12/2000 09:20:12 PM
# Transport DtTm                                                          NaN
# Hospital DtTm                                                           NaN
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 09:24:19 PM
# Address                                               100 Block of JONES ST
# City                                                                     SF
# Zipcode of Incident                                                   94102
# Battalion                                                               B03
# Station Area                                                              1
# Box                                                                    1456
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                            ENGINE
# Unit sequence in call dispatch                                            3
# Fire Prevention District                                                  3
# Supervisor District                                                       6
# Neighborhooods - Analysis Boundaries                             Tenderloin
# Location                              (37.7825474000421, -122.412247935495)
# RowID                                                         001030107-E01
#
#                                                                           4
# Call Number                                                         1030108
# Unit ID                                                                 RS1
# Incident Number                                                       30616
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:14:43 PM
# Entry DtTm                                           04/12/2000 09:16:11 PM
# Dispatch DtTm                                        04/12/2000 09:16:24 PM
# Response DtTm                                        04/12/2000 09:18:20 PM
# On Scene DtTm                                        04/12/2000 09:20:08 PM
# Transport DtTm                                                          NaN
# Hospital DtTm                                                           NaN
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 09:20:36 PM
# Address                                              700 Block of MARKET ST
# City                                                                     SF
# Zipcode of Incident                                                   94108
# Battalion                                                               B03
# Station Area                                                              1
# Box                                                                    1322
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                      RESCUE SQUAD
# Unit sequence in call dispatch                                            2
# Fire Prevention District                                                  1
# Supervisor District                                                       3
# Neighborhooods - Analysis Boundaries         Financial District/South Beach
# Location                              (37.7863072236365, -122.405294845215)
# RowID                                                         001030108-RS1

# %%
optimized_df.head().T
# Out:
#                                                                           0  \
# Call Number                                                         1030101
# Unit ID                                                                 E18
# Incident Number                                                      306091
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:00:29 PM
# Entry DtTm                                           04/12/2000 09:01:40 PM
# Dispatch DtTm                                        04/12/2000 09:02:00 PM
# Response DtTm                                                           NaN
# On Scene DtTm                                                           NaN
# Transport DtTm                                                          NaN
# Hospital DtTm                                                           NaN
# Call Final Disposition                                                Other
# Available DtTm                                                          NaN
# Address                                              2000 Block of 37TH AVE
# City                                                                     SF
# Zipcode of Incident                                                   94116
# Battalion                                                               B08
# Station Area                                                             18
# Box                                                                     757
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                            ENGINE
# Unit sequence in call dispatch                                            1
# Fire Prevention District                                                  8
# Supervisor District                                                       4
# Neighborhooods - Analysis Boundaries                        Sunset/Parkside
# Location                              (37.7487247711275, -122.495504020186)
# RowID                                                         001030101-E18
#
#                                                                           1  \
# Call Number                                                         1030104
# Unit ID                                                                 M14
# Incident Number                                                       30612
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:09:02 PM
# Entry DtTm                                           04/12/2000 09:10:17 PM
# Dispatch DtTm                                        04/12/2000 09:10:29 PM
# Response DtTm                                        04/12/2000 09:12:11 PM
# On Scene DtTm                                        04/12/2000 09:19:36 PM
# Transport DtTm                                       04/12/2000 09:43:57 PM
# Hospital DtTm                                        04/12/2000 10:03:33 PM
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 10:23:57 PM
# Address                                              1700 Block of 43RD AVE
# City                                                                     SF
# Zipcode of Incident                                                   94122
# Battalion                                                               B08
# Station Area                                                             23
# Box                                                                    7651
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                               True
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                             MEDIC
# Unit sequence in call dispatch                                            2
# Fire Prevention District                                                  8
# Supervisor District                                                       4
# Neighborhooods - Analysis Boundaries                        Sunset/Parkside
# Location                              (37.7540326780595, -122.502185504543)
# RowID                                                         001030104-M14
#
#                                                                           2  \
# Call Number                                                         1030106
# Unit ID                                                                 M36
# Incident Number                                                       30614
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:09:44 PM
# Entry DtTm                                           04/12/2000 09:10:56 PM
# Dispatch DtTm                                        04/12/2000 09:11:47 PM
# Response DtTm                                                           NaN
# On Scene DtTm                                        04/12/2000 09:14:11 PM
# Transport DtTm                                       04/12/2000 09:59:31 PM
# Hospital DtTm                                        04/12/2000 10:10:06 PM
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 10:43:40 PM
# Address                                                  0 Block of FELL ST
# City                                                                     SF
# Zipcode of Incident                                                   94102
# Battalion                                                               B02
# Station Area                                                             36
# Box                                                                    3111
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                             MEDIC
# Unit sequence in call dispatch                                            1
# Fire Prevention District                                                  2
# Supervisor District                                                       6
# Neighborhooods - Analysis Boundaries                             Tenderloin
# Location                              (37.7764405100838, -122.418481123408)
# RowID                                                         001030106-M36
#
#                                                                           3  \
# Call Number                                                         1030107
# Unit ID                                                                 E01
# Incident Number                                                       30615
# Call Type                                                            Alarms
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:13:47 PM
# Entry DtTm                                           04/12/2000 09:13:51 PM
# Dispatch DtTm                                        04/12/2000 09:14:13 PM
# Response DtTm                                        04/12/2000 09:15:58 PM
# On Scene DtTm                                        04/12/2000 09:20:12 PM
# Transport DtTm                                                          NaN
# Hospital DtTm                                                           NaN
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 09:24:19 PM
# Address                                               100 Block of JONES ST
# City                                                                     SF
# Zipcode of Incident                                                   94102
# Battalion                                                               B03
# Station Area                                                              1
# Box                                                                    1456
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                            ENGINE
# Unit sequence in call dispatch                                            3
# Fire Prevention District                                                  3
# Supervisor District                                                       6
# Neighborhooods - Analysis Boundaries                             Tenderloin
# Location                              (37.7825474000421, -122.412247935495)
# RowID                                                         001030107-E01
#
#                                                                           4
# Call Number                                                         1030108
# Unit ID                                                                 RS1
# Incident Number                                                       30616
# Call Type                                                  Medical Incident
# Call Date                                                        04/12/2000
# Watch Date                                                       04/12/2000
# Received DtTm                                        04/12/2000 09:14:43 PM
# Entry DtTm                                           04/12/2000 09:16:11 PM
# Dispatch DtTm                                        04/12/2000 09:16:24 PM
# Response DtTm                                        04/12/2000 09:18:20 PM
# On Scene DtTm                                        04/12/2000 09:20:08 PM
# Transport DtTm                                                          NaN
# Hospital DtTm                                                           NaN
# Call Final Disposition                                                Other
# Available DtTm                                       04/12/2000 09:20:36 PM
# Address                                              700 Block of MARKET ST
# City                                                                     SF
# Zipcode of Incident                                                   94108
# Battalion                                                               B03
# Station Area                                                              1
# Box                                                                    1322
# Original Priority                                                         3
# Priority                                                                  3
# Final Priority                                                            3
# ALS Unit                                                              False
# Call Type Group                                                         NaN
# Number of Alarms                                                          1
# Unit Type                                                      RESCUE SQUAD
# Unit sequence in call dispatch                                            2
# Fire Prevention District                                                  1
# Supervisor District                                                       3
# Neighborhooods - Analysis Boundaries         Financial District/South Beach
# Location                              (37.7863072236365, -122.405294845215)
# RowID                                                         001030108-RS1

# %%
optimized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4715699 entries, 0 to 4715698
# Data columns (total 34 columns):
# Call Number                             uint32
# Unit ID                                 object
# Incident Number                         uint32
# Call Type                               object
# Call Date                               object
# Watch Date                              object
# Received DtTm                           object
# Entry DtTm                              object
# Dispatch DtTm                           object
# Response DtTm                           object
# On Scene DtTm                           object
# Transport DtTm                          object
# Hospital DtTm                           object
# Call Final Disposition                  object
# Available DtTm                          object
# Address                                 object
# City                                    object
# Zipcode of Incident                     float32
# Battalion                               object
# Station Area                            object
# Box                                     object
# Original Priority                       object
# Priority                                object
# Final Priority                          uint8
# ALS Unit                                bool
# Call Type Group                         object
# Number of Alarms                        uint8
# Unit Type                               object
# Unit sequence in call dispatch          float32
# Fire Prevention District                object
# Supervisor District                     object
# Neighborhooods - Analysis Boundaries    object
# Location                                object
# RowID                                   object
# dtypes: bool(1), float32(2), object(27), uint32(2), uint8(2)
# memory usage: 1.0+ GB

# %% [markdown]
# ideas: https://www.dataquest.io/blog/pandas-big-data/
