# %%
import pandas as pd

# %%
info = pd.read_excel('FIR-0002_DataDictionary_fire-calls-for-service.xlsx')

# %%
info.drop(columns=['Unnamed: 0'], inplace=True)

# %%
info.drop([0,1,2], axis = 0,inplace=True)

# %%
info.columns= ['Field Name','Data Type', 'Definition', 'Notes']

# %%
info = info[:-37]

# %%
info
# Out:
#                         Field Name             Data Type  \
# 3                      Call Number                  Text
# 4                          Unit ID                  Text
# 5                  Incident Number                  Text
# 6                        Call Date           Date & Time
# 7                        Call Type                  Text
# 8                       Watch Date           Date & Time
# 9                    Received DtTm           Date & Time
# 10                      Entry DtTm           Date & Time
# 11                   Dispatch DtTm           Date & Time
# 12                   Response DtTm           Date & Time
# 13                   On Scene DtTm           Date & Time
# 14     AVL Validated On Scene DtTm           Date & Time
# 15                  Transport DtTm           Date & Time
# 16                   Hospital DtTm           Date & Time
# 17          Call Final Disposition                  Text
# ...
